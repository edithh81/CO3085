# %%
# !git clone https://github.com/edithh81/CO3085.git
# Out:
# fatal: destination path 'CO3085' already exists and is not an empty directory.

# %%
# !pip install evaluate
# !pip install bitsandbytes
# !pip install git+https://github.com/huggingface/accelerate.git
# Out:
# ...
#   Cloning https://github.com/huggingface/accelerate.git to /tmp/pip-req-build-dkgkxgfn
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/accelerate.git /tmp/pip-req-build-dkgkxgfn
#   Resolved https://github.com/huggingface/accelerate.git to commit a72834ca8996f882208d4946d9180e626ae5c9c8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# !sudo apt-get install python3.11
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.11 is already the newest version (3.11.14-1+jammy1).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.

# %%
# !apt install python3.11-venv
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.11-venv is already the newest version (3.11.14-1+jammy1).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.

# %%
# !python3.11 -m venv rag-venv

# %%
# !/content/rag-venv/bin/python3.11 -m pip install -r /content/CO3085/requirements.txt
# Out:
# ...
# WARNING: typer 0.20.0 does not provide the extra 'all'
# ...

# %%
# !MPLBACKEND=Agg /content/rag-venv/bin/python3.11 /content/CO3085/app.py
# Out:
# Initializing chatbot...
# Loading embedding model...
# Building FAISS index...
# Index built with 55 items
# Using device: cuda
# Loading: vilm/vinallama-7b-chat
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loading checkpoint shards:   0% 0/3 [00:27<?, ?it/s]
# Traceback (most recent call last):
#   File "/content/CO3085/app.py", line 7, in <module>
#     bot = FoodOrderChatbot()
#           ^^^^^^^^^^^^^^^^^^
#   File "/content/CO3085/chatbot.py", line 11, in __init__
#     self.llm = LLMHandler()
#                ^^^^^^^^^^^^
#   File "/content/CO3085/llm_handler.py", line 18, in __init__
#     self.model, self.tokenizer = self._load_model(model_to_load)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/CO3085/llm_handler.py", line 44, in _load_model
#     model = AutoModelForCausalLM.from_pretrained(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
